# %%
import numpy as np
from collections import namedtuple
import random
import torch
from torch import nn, optim
import torch.nn.functional as F

from tetris_env import Tetris

BATCH_SIZE = 32
CAPACITY = 10000

Transition = namedtuple("Transition", ("state", "action", "next_state", "reward"))

GAMMA = 0.99
MAX_STEPS = 14
NUM_EPISODES = 5000
TARGET_SCORE = 4

class ReplayMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0
    
    def push(self, state, action, state_next, reward):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        
        self.memory[self.index] = Transition(state, action, state_next, reward)
        self.index = (self.index + 1) % self.capacity
    
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

class Net(nn.Module):
    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3_adv = nn.Linear(n_mid, n_out)
        self.fc3_v = nn.Linear(n_mid, 1)

    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))

        adv = self.fc3_adv(h2)
        val = self.fc3_v(h2).expand(-1, adv.size(1))

        output = val + adv - adv.mean(1, keepdim=True).expand(-1, adv.size(1))

        return output

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions # まぁ0..39の40個なんだけどね
        self.memory = ReplayMemory(CAPACITY)

        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)
        self.target_q_network = Net(n_in, n_mid, n_out)

        # print(self.main_q_network)

        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001)
    
    def replay(self):
        if len(self.memory) < BATCH_SIZE:
            return

        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()
        self.expected_state_action_values = self.get_expected_state_action_values()
        self.update_main_q_network()

    def decide_action(self, state, episode):
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
        
        else:
            action = torch.LongTensor([[random.randrange(self.num_actions)]])
        
        return action
    
    def make_minibatch(self):
        transitions = self.memory.sample(BATCH_SIZE)
        batch = Transition(*zip(*transitions))
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        self.main_q_network.eval()
        self.target_q_network.eval()

        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))

        next_state_values = torch.zeros(BATCH_SIZE)

        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)

        a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(1)[1]

        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        expected_state_action_values = self.reward_batch + GAMMA * next_state_values

        return expected_state_action_values

    def update_main_q_network(self):
        self.main_q_network.train()
        loss = F.smooth_l1_loss(self.state_action_values, self.expected_state_action_values.unsqueeze(1))

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
    
    def update_target_q_network(self):
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)

    def update_q_function(self):
        self.brain.replay()
    
    def get_action(self, state, episode):
        action = self.brain.decide_action(state, episode)
        return action
    
    def memorize(self, state, action, state_next, reward):
        self.brain.memory.push(state, action, state_next, reward)
    
    def update_target_q_function(self):
        self.brain.update_target_q_network()

## ここから要注意

def make_observation(am, field):
    observation = np.array(field)
    observation = np.append(observation, am)
    return observation

class Environment:
    def __init__(self):
        self.env = Tetris()
        # self.num_states = self.env.observation_space.shape[0]
        self.num_states = 211 # <= 20 * 11 + 1(降ってきているブロック)
        # self.num_actions = self.env.action_space.n
        self.num_actions = 40 # <= [north, east, south, west] * 10

        self.agent = Agent(self.num_states, self.num_actions)
    
    def run(self):
        episode_10_list = np.zeros(10)

        complete_episodes = 0 # scoreがTARGET_SCORE以上になった試行数
        episode_final = False
        # frames = []

        for episode in range(NUM_EPISODES):
            am, field = self.env.reset()
            observation = make_observation(am, field)
            state = torch.from_numpy(observation).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)

            sum_reward = 0
            sum_density_reward = 0

            for step in range(MAX_STEPS):
                action = self.agent.get_action(state, episode)
                am, field, step_reward, done = self.env.step(action.item())
                observation_next = make_observation(am, field)

                real_score = step_reward // 1
                sum_reward += real_score
                sum_density_reward += step_reward - real_score

                if done:
                    state_next = None

                    episode_10_list = np.hstack((episode_10_list[1:], sum_reward))

                    if step < (MAX_STEPS-1): # 窒息死
                        reward = torch.FloatTensor([-10.0])
                    else:
                        reward = torch.FloatTensor([float(step_reward)]) # 報酬はいつも通り
                    
                    if sum_reward < TARGET_SCORE:
                        complete_episodes = 0
                    else:
                        complete_episodes += 1
                
                else:
                    reward = torch.FloatTensor([float(step_reward)])
                    state_next = torch.from_numpy(observation_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)
                
                self.agent.memorize(state, action, state_next, reward)
                self.agent.update_q_function()
                state = state_next
                    
                if done:
                    print(f"{episode} Episode: Finished with score {sum_reward} ; density_score {sum_density_reward / 14} : 10試行の平均SCORE = {episode_10_list.mean():.1f}")
                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break
                    
            if episode_final is True:
                print("episode final's score:", sum_reward)
                break

            if complete_episodes >= 10:
                print(f"10回連続{TARGET_SCORE}点越え")
                episode_final = True

tetris_envi = Environment()
tetris_envi.run()
# Out:
# 0 Episode: Finished with score 0.0 ; density_score 0.21212069676355386 : 10試行の平均SCORE = 0.0
# 1 Episode: Finished with score 0.0 ; density_score 0.2391267462696034 : 10試行の平均SCORE = 0.0
# 2 Episode: Finished with score 0.0 ; density_score 0.2112018140589569 : 10試行の平均SCORE = 0.0
# 3 Episode: Finished with score 0.0 ; density_score 0.16221492645641253 : 10試行の平均SCORE = 0.0
# 4 Episode: Finished with score 0.0 ; density_score 0.16925221603793036 : 10試行の平均SCORE = 0.0
# 466 Episode: Finished with score 1.0 ; density_score 0.3828571428571429 : 10試行の平均SCORE = 0.3
# 467 Episode: Finished with score 0.0 ; density_score 0.4094086865515437 : 10試行の平均SCORE = 0.3
# 468 Episode: Finished with score 0.0 ; density_score 0.4277760334903192 : 10試行の平均SCORE = 0.3
# 469 Episode: Finished with score 0.0 ; density_score 0.38122655122655125 : 10試行の平均SCORE = 0.3
# 470 Episode: Finished with score 0.0 ; density_score 0.4483704390847248 : 10試行の平均SCORE = 0.3
# 471 Episode: Finished with score 0.0 ; density_score 0.40421768707482997 : 10試行の平均SCORE = 0.2
# 472 Episode: Finished with score 0.0 ; density_score 0.39798701298701294 : 10試行の平均SCORE = 0.2
# 473 Episode: Finished with score 0.0 ; density_score 0.3045392889090368 : 10試行の平均SCORE = 0.2
# 474 Episode: Finished with score 1.0 ; density_score 0.4302437641723357 : 10試行の平均SCORE = 0.3
# 475 Episode: Finished with score 0.0 ; density_score 0.4024489795918368 : 10試行の平均SCORE = 0.2
# 476 Episode: Finished with score 0.0 ; density_score 0.3824768089053803 : 10試行の平均SCORE = 0.1
# 477 Episode: Finished with score 0.0 ; density_score 0.33240188383045527 : 10試行の平均SCORE = 0.1
# 478 Episode: Finished with score 0.0 ; density_score 0.3333333333333333 : 10試行の平均SCORE = 0.1
# 479 Episode: Finished with score 0.0 ; density_score 0.3869222840651411 : 10試行の平均SCORE = 0.1
# 480 Episode: Finished with score 0.0 ; density_score 0.36519480519480524 : 10試行の平均SCORE = 0.1
# 481 Episode: Finished with score 0.0 ; density_score 0.2601579579200101 : 10試行の平均SCORE = 0.1
# 482 Episode: Finished with score 0.0 ; density_score 0.36117810760667907 : 10試行の平均SCORE = 0.1
# 483 Episode: Finished with score 0.0 ; density_score 0.29749389499389495 : 10試行の平均SCORE = 0.1
# 484 Episode: Finished with score 0.0 ; density_score 0.3067832167832168 : 10試行の平均SCORE = 0.0
# 485 Episode: Finished with score 0.0 ; density_score 0.3457692307692308 : 10試行の平均SCORE = 0.0
# 486 Episode: Finished with score 0.0 ; density_score 0.41400535971964547 : 10試行の平均SCORE = 0.0
# 487 Episode: Finished with score 0.0 ; density_score 0.3342630385487528 : 10試行の平均SCORE = 0.0
# 488 Episode: Finished with score 0.0 ; density_score 0.402576788291074 : 10試行の平均SCORE = 0.0
# 489 Episode: Finished with score 0.0 ; density_score 0.38987837559266136 : 10試行の平均SCORE = 0.0
# 490 Episode: Finished with score 0.0 ; density_score 0.3742290249433106 : 10試行の平均SCORE = 0.0
# 491 Episode: Finished with score 0.0 ; density_score 0.34625850340136044 : 10試行の平均SCORE = 0.0
# 492 Episode: Finished with score 0.0 ; density_score 0.32297936190793336 : 10試行の平均SCORE = 0.0
# 493 Episode: Finished with score 0.0 ; density_score 0.3588827838827839 : 10試行の平均SCORE = 0.0
# 494 Episode: Finished with score 0.0 ; density_score 0.3382993197278911 : 10試行の平均SCORE = 0.0
# 495 Episode: Finished with score 0.0 ; density_score 0.3662237762237762 : 10試行の平均SCORE = 0.0
# 496 Episode: Finished with score 0.0 ; density_score 0.3604812694308493 : 10試行の平均SCORE = 0.0
# 497 Episode: Finished with score 0.0 ; density_score 0.39223665223665216 : 10試行の平均SCORE = 0.0
# 498 Episode: Finished with score 0.0 ; density_score 0.41322510822510816 : 10試行の平均SCORE = 0.0
# 499 Episode: Finished with score 0.0 ; density_score 0.40707792207792204 : 10試行の平均SCORE = 0.0
# 500 Episode: Finished with score 0.0 ; density_score 0.3567903525046382 : 10試行の平均SCORE = 0.0
# 501 Episode: Finished with score 0.0 ; density_score 0.3313243502529217 : 10試行の平均SCORE = 0.0
# 502 Episode: Finished with score 0.0 ; density_score 0.3981292517006803 : 10試行の平均SCORE = 0.0
# 503 Episode: Finished with score 0.0 ; density_score 0.3223671170099741 : 10試行の平均SCORE = 0.0
# 504 Episode: Finished with score 0.0 ; density_score 0.40150896722325297 : 10試行の平均SCORE = 0.0
# 505 Episode: Finished with score 1.0 ; density_score 0.40484126984126984 : 10試行の平均SCORE = 0.1
# 506 Episode: Finished with score 0.0 ; density_score 0.36949082663368377 : 10試行の平均SCORE = 0.1
# 507 Episode: Finished with score 0.0 ; density_score 0.32695657283892576 : 10試行の平均SCORE = 0.1
# 508 Episode: Finished with score 0.0 ; density_score 0.35408163265306125 : 10試行の平均SCORE = 0.1
# 509 Episode: Finished with score 0.0 ; density_score 0.41671511028653896 : 10試行の平均SCORE = 0.1
# 510 Episode: Finished with score 0.0 ; density_score 0.31838784231641365 : 10試行の平均SCORE = 0.1
# 511 Episode: Finished with score 0.0 ; density_score 0.4607173778602349 : 10試行の平均SCORE = 0.1
# 512 Episode: Finished with score 0.0 ; density_score 0.37703122274550854 : 10試行の平均SCORE = 0.1
# 513 Episode: Finished with score 0.0 ; density_score 0.3517216117216117 : 10試行の平均SCORE = 0.1
# 514 Episode: Finished with score 0.0 ; density_score 0.35667015524158385 : 10試行の平均SCORE = 0.1
# ...
# 2992 Episode: Finished with score 0.0 ; density_score 0.48833642547928263 : 10試行の平均SCORE = 0.1
# 2993 Episode: Finished with score 0.0 ; density_score 0.5023809523809523 : 10試行の平均SCORE = 0.1
# 2994 Episode: Finished with score 0.0 ; density_score 0.5187301587301587 : 10試行の平均SCORE = 0.1
# 2995 Episode: Finished with score 0.0 ; density_score 0.4854225932797361 : 10試行の平均SCORE = 0.1
# 2996 Episode: Finished with score 2.0 ; density_score 0.5197619047619048 : 10試行の平均SCORE = 0.3
# 2997 Episode: Finished with score 0.0 ; density_score 0.5355442176870747 : 10試行の平均SCORE = 0.3
# 2998 Episode: Finished with score 0.0 ; density_score 0.4831776953205524 : 10試行の平均SCORE = 0.2
# 2999 Episode: Finished with score 0.0 ; density_score 0.5033333333333332 : 10試行の平均SCORE = 0.2
# 3000 Episode: Finished with score 0.0 ; density_score 0.5196598639455782 : 10試行の平均SCORE = 0.2
# 3001 Episode: Finished with score 0.0 ; density_score 0.5123840445269017 : 10試行の平均SCORE = 0.2
# 3002 Episode: Finished with score 0.0 ; density_score 0.5295918367346938 : 10試行の平均SCORE = 0.2
# 3003 Episode: Finished with score 0.0 ; density_score 0.5030839002267573 : 10試行の平均SCORE = 0.2
# 3004 Episode: Finished with score 0.0 ; density_score 0.4809245516388373 : 10試行の平均SCORE = 0.2
# 3005 Episode: Finished with score 0.0 ; density_score 0.5448979591836735 : 10試行の平均SCORE = 0.2
# 3006 Episode: Finished with score 0.0 ; density_score 0.4578117913832199 : 10試行の平均SCORE = 0.0
# 3007 Episode: Finished with score 0.0 ; density_score 0.5800680272108844 : 10試行の平均SCORE = 0.0
# 3008 Episode: Finished with score 0.0 ; density_score 0.5003401360544216 : 10試行の平均SCORE = 0.0
# 3009 Episode: Finished with score 0.0 ; density_score 0.5238095238095237 : 10試行の平均SCORE = 0.0
# 3010 Episode: Finished with score 1.0 ; density_score 0.4547619047619048 : 10試行の平均SCORE = 0.1
# 3011 Episode: Finished with score 0.0 ; density_score 0.5384693877551021 : 10試行の平均SCORE = 0.1
# 3012 Episode: Finished with score 0.0 ; density_score 0.5052607709750567 : 10試行の平均SCORE = 0.1
# 3013 Episode: Finished with score 0.0 ; density_score 0.5712585034013606 : 10試行の平均SCORE = 0.1
# 3014 Episode: Finished with score 0.0 ; density_score 0.5048783755926612 : 10試行の平均SCORE = 0.1
# 3015 Episode: Finished with score 0.0 ; density_score 0.5713605442176871 : 10試行の平均SCORE = 0.1
# 3016 Episode: Finished with score 0.0 ; density_score 0.5213203463203462 : 10試行の平均SCORE = 0.1
# 3017 Episode: Finished with score 1.0 ; density_score 0.5561224489795918 : 10試行の平均SCORE = 0.2
# 3018 Episode: Finished with score 0.0 ; density_score 0.5066810966810966 : 10試行の平均SCORE = 0.2
# 3019 Episode: Finished with score 0.0 ; density_score 0.5052380952380953 : 10試行の平均SCORE = 0.2
# 3020 Episode: Finished with score 0.0 ; density_score 0.5746598639455781 : 10試行の平均SCORE = 0.1
# 3021 Episode: Finished with score 0.0 ; density_score 0.5223809523809523 : 10試行の平均SCORE = 0.1
# 3022 Episode: Finished with score 0.0 ; density_score 0.47049062049062046 : 10試行の平均SCORE = 0.1
# 3023 Episode: Finished with score 0.0 ; density_score 0.5003061224489797 : 10試行の平均SCORE = 0.1
# 3024 Episode: Finished with score 0.0 ; density_score 0.5329120879120879 : 10試行の平均SCORE = 0.1
# 3025 Episode: Finished with score 0.0 ; density_score 0.5185714285714285 : 10試行の平均SCORE = 0.1
# 3026 Episode: Finished with score 0.0 ; density_score 0.4857967429396 : 10試行の平均SCORE = 0.1
# 3027 Episode: Finished with score 1.0 ; density_score 0.5348072562358276 : 10試行の平均SCORE = 0.1
# 3028 Episode: Finished with score 0.0 ; density_score 0.577437641723356 : 10試行の平均SCORE = 0.1
# 3029 Episode: Finished with score 0.0 ; density_score 0.5003854875283446 : 10試行の平均SCORE = 0.1
# 3030 Episode: Finished with score 0.0 ; density_score 0.5398299319727891 : 10試行の平均SCORE = 0.1
# 3031 Episode: Finished with score 1.0 ; density_score 0.5312755102040815 : 10試行の平均SCORE = 0.2
# 3032 Episode: Finished with score 1.0 ; density_score 0.46775510204081633 : 10試行の平均SCORE = 0.3
# 3033 Episode: Finished with score 0.0 ; density_score 0.45081632653061227 : 10試行の平均SCORE = 0.3
# 3034 Episode: Finished with score 0.0 ; density_score 0.5479251700680272 : 10試行の平均SCORE = 0.3
# 3035 Episode: Finished with score 0.0 ; density_score 0.5415873015873016 : 10試行の平均SCORE = 0.3
# 3036 Episode: Finished with score 0.0 ; density_score 0.5452380952380951 : 10試行の平均SCORE = 0.3
# 3037 Episode: Finished with score 1.0 ; density_score 0.5172789115646259 : 10試行の平均SCORE = 0.3
# 3038 Episode: Finished with score 0.0 ; density_score 0.4939665096807953 : 10試行の平均SCORE = 0.3
# 3039 Episode: Finished with score 1.0 ; density_score 0.5312698412698412 : 10試行の平均SCORE = 0.4
# 3040 Episode: Finished with score 0.0 ; density_score 0.5648185941043083 : 10試行の平均SCORE = 0.4
# 3041 Episode: Finished with score 0.0 ; density_score 0.48809523809523814 : 10試行の平均SCORE = 0.3
# 3042 Episode: Finished with score 0.0 ; density_score 0.5647619047619047 : 10試行の平均SCORE = 0.2
# 3043 Episode: Finished with score 0.0 ; density_score 0.49295918367346936 : 10試行の平均SCORE = 0.2
# 3044 Episode: Finished with score 0.0 ; density_score 0.49809523809523804 : 10試行の平均SCORE = 0.2
# 3045 Episode: Finished with score 0.0 ; density_score 0.5357142857142857 : 10試行の平均SCORE = 0.2
# 3046 Episode: Finished with score 0.0 ; density_score 0.5300144300144299 : 10試行の平均SCORE = 0.2
# 3047 Episode: Finished with score 0.0 ; density_score 0.50375283446712 : 10試行の平均SCORE = 0.1
# 3048 Episode: Finished with score 0.0 ; density_score 0.5143083900226756 : 10試行の平均SCORE = 0.1
# 3049 Episode: Finished with score 1.0 ; density_score 0.5232142857142856 : 10試行の平均SCORE = 0.1
# 3050 Episode: Finished with score 0.0 ; density_score 0.5351814058956915 : 10試行の平均SCORE = 0.1
# 3051 Episode: Finished with score 0.0 ; density_score 0.4843764172335601 : 10試行の平均SCORE = 0.1
# 3052 Episode: Finished with score 0.0 ; density_score 0.5414316635745208 : 10試行の平均SCORE = 0.1
# 3053 Episode: Finished with score 0.0 ; density_score 0.5802380952380952 : 10試行の平均SCORE = 0.1
# 3054 Episode: Finished with score 0.0 ; density_score 0.5086394557823128 : 10試行の平均SCORE = 0.1
# 3055 Episode: Finished with score 0.0 ; density_score 0.5257142857142857 : 10試行の平均SCORE = 0.1
# 3056 Episode: Finished with score 0.0 ; density_score 0.5071541950113377 : 10試行の平均SCORE = 0.1
# 3057 Episode: Finished with score 0.0 ; density_score 0.5061791383219953 : 10試行の平均SCORE = 0.1
# 3058 Episode: Finished with score 0.0 ; density_score 0.4860770975056689 : 10試行の平均SCORE = 0.1
# 3059 Episode: Finished with score 1.0 ; density_score 0.4756462585034013 : 10試行の平均SCORE = 0.1
# 3060 Episode: Finished with score 0.0 ; density_score 0.485657596371882 : 10試行の平均SCORE = 0.1
# 3061 Episode: Finished with score 0.0 ; density_score 0.5633219954648527 : 10試行の平均SCORE = 0.1
# 3062 Episode: Finished with score 0.0 ; density_score 0.48361678004535147 : 10試行の平均SCORE = 0.1
# 3063 Episode: Finished with score 0.0 ; density_score 0.5258730158730158 : 10試行の平均SCORE = 0.1
# 3064 Episode: Finished with score 0.0 ; density_score 0.5134920634920634 : 10試行の平均SCORE = 0.1
# 3065 Episode: Finished with score 0.0 ; density_score 0.46382395382395375 : 10試行の平均SCORE = 0.1
# 3066 Episode: Finished with score 0.0 ; density_score 0.5294557823129251 : 10試行の平均SCORE = 0.1
# 3067 Episode: Finished with score 0.0 ; density_score 0.528265306122449 : 10試行の平均SCORE = 0.1
# 3068 Episode: Finished with score 1.0 ; density_score 0.4959977324263038 : 10試行の平均SCORE = 0.2
# 3069 Episode: Finished with score 0.0 ; density_score 0.5084013605442177 : 10試行の平均SCORE = 0.1
# 3070 Episode: Finished with score 0.0 ; density_score 0.5132312925170069 : 10試行の平均SCORE = 0.1
# 3071 Episode: Finished with score 0.0 ; density_score 0.5250113378684806 : 10試行の平均SCORE = 0.1
# 3072 Episode: Finished with score 0.0 ; density_score 0.5304988662131519 : 10試行の平均SCORE = 0.1
# 3073 Episode: Finished with score 0.0 ; density_score 0.533469387755102 : 10試行の平均SCORE = 0.1
# 3074 Episode: Finished with score 0.0 ; density_score 0.4757939679368251 : 10試行の平均SCORE = 0.1
# 3075 Episode: Finished with score 0.0 ; density_score 0.543469387755102 : 10試行の平均SCORE = 0.1
# 3076 Episode: Finished with score 0.0 ; density_score 0.5139115646258503 : 10試行の平均SCORE = 0.1
# 3077 Episode: Finished with score 0.0 ; density_score 0.5081323438466295 : 10試行の平均SCORE = 0.1
# 3078 Episode: Finished with score 0.0 ; density_score 0.5063492063492063 : 10試行の平均SCORE = 0.0
# 3079 Episode: Finished with score 0.0 ; density_score 0.4899433106575963 : 10試行の平均SCORE = 0.0
# 3080 Episode: Finished with score 0.0 ; density_score 0.45628117913832206 : 10試行の平均SCORE = 0.0
# 3081 Episode: Finished with score 0.0 ; density_score 0.4882086167800453 : 10試行の平均SCORE = 0.0
# 3082 Episode: Finished with score 0.0 ; density_score 0.5102380952380952 : 10試行の平均SCORE = 0.0
# 3083 Episode: Finished with score 1.0 ; density_score 0.5009523809523809 : 10試行の平均SCORE = 0.1
# 3084 Episode: Finished with score 0.0 ; density_score 0.5483333333333333 : 10試行の平均SCORE = 0.1
# 3085 Episode: Finished with score 1.0 ; density_score 0.4922789115646259 : 10試行の平均SCORE = 0.2
# 3086 Episode: Finished with score 0.0 ; density_score 0.5247619047619049 : 10試行の平均SCORE = 0.2
# 3087 Episode: Finished with score 0.0 ; density_score 0.48928571428571427 : 10試行の平均SCORE = 0.2
# 3088 Episode: Finished with score 0.0 ; density_score 0.4784013605442177 : 10試行の平均SCORE = 0.2
# 3089 Episode: Finished with score 0.0 ; density_score 0.5234353741496598 : 10試行の平均SCORE = 0.2
# 3090 Episode: Finished with score 0.0 ; density_score 0.5248639455782314 : 10試行の平均SCORE = 0.2
# 3091 Episode: Finished with score 0.0 ; density_score 0.5135714285714286 : 10試行の平均SCORE = 0.2
# 3092 Episode: Finished with score 1.0 ; density_score 0.47496031746031747 : 10試行の平均SCORE = 0.3
# 3093 Episode: Finished with score 0.0 ; density_score 0.5206122448979592 : 10試行の平均SCORE = 0.2
# 3094 Episode: Finished with score 0.0 ; density_score 0.5233333333333333 : 10試行の平均SCORE = 0.2
# 3095 Episode: Finished with score 0.0 ; density_score 0.4462585034013605 : 10試行の平均SCORE = 0.1
# 3096 Episode: Finished with score 0.0 ; density_score 0.4891156462585033 : 10試行の平均SCORE = 0.1
# 3097 Episode: Finished with score 0.0 ; density_score 0.518015873015873 : 10試行の平均SCORE = 0.1
# 3098 Episode: Finished with score 0.0 ; density_score 0.506609977324263 : 10試行の平均SCORE = 0.1
# 3099 Episode: Finished with score 0.0 ; density_score 0.476814058956916 : 10試行の平均SCORE = 0.1
# 3100 Episode: Finished with score 0.0 ; density_score 0.5361111111111112 : 10試行の平均SCORE = 0.1
# 3101 Episode: Finished with score 1.0 ; density_score 0.4749092970521542 : 10試行の平均SCORE = 0.2
# 3102 Episode: Finished with score 0.0 ; density_score 0.47542259327973607 : 10試行の平均SCORE = 0.1
# 3103 Episode: Finished with score 0.0 ; density_score 0.4555991627420199 : 10試行の平均SCORE = 0.1
# 3104 Episode: Finished with score 0.0 ; density_score 0.5316893424036281 : 10試行の平均SCORE = 0.1
# 3105 Episode: Finished with score 0.0 ; density_score 0.49523809523809514 : 10試行の平均SCORE = 0.1
# 3106 Episode: Finished with score 0.0 ; density_score 0.479750566893424 : 10試行の平均SCORE = 0.1
# 3107 Episode: Finished with score 0.0 ; density_score 0.4349453720882292 : 10試行の平均SCORE = 0.1
# 3108 Episode: Finished with score 0.0 ; density_score 0.43476190476190485 : 10試行の平均SCORE = 0.1
# 3109 Episode: Finished with score 0.0 ; density_score 0.5280952380952381 : 10試行の平均SCORE = 0.1
# 3110 Episode: Finished with score 0.0 ; density_score 0.517312925170068 : 10試行の平均SCORE = 0.1
# 3111 Episode: Finished with score 0.0 ; density_score 0.43666666666666665 : 10試行の平均SCORE = 0.0
# 3112 Episode: Finished with score 0.0 ; density_score 0.49730158730158724 : 10試行の平均SCORE = 0.0
# 3113 Episode: Finished with score 0.0 ; density_score 0.4623376623376623 : 10試行の平均SCORE = 0.0
# 3114 Episode: Finished with score 0.0 ; density_score 0.47216378859236 : 10試行の平均SCORE = 0.0
# 3115 Episode: Finished with score 0.0 ; density_score 0.5239569160997732 : 10試行の平均SCORE = 0.0
# 3116 Episode: Finished with score 0.0 ; density_score 0.5188239538239537 : 10試行の平均SCORE = 0.0
# 3117 Episode: Finished with score 0.0 ; density_score 0.5633219954648527 : 10試行の平均SCORE = 0.0
# 3118 Episode: Finished with score 0.0 ; density_score 0.5090476190476191 : 10試行の平均SCORE = 0.0
# 3119 Episode: Finished with score 0.0 ; density_score 0.552517006802721 : 10試行の平均SCORE = 0.0
# 3120 Episode: Finished with score 1.0 ; density_score 0.5362868480725623 : 10試行の平均SCORE = 0.1
# 3121 Episode: Finished with score 0.0 ; density_score 0.5169387755102042 : 10試行の平均SCORE = 0.1
# 3122 Episode: Finished with score 0.0 ; density_score 0.49968079539508103 : 10試行の平均SCORE = 0.1
# 3123 Episode: Finished with score 0.0 ; density_score 0.5084126984126983 : 10試行の平均SCORE = 0.1
# 3124 Episode: Finished with score 0.0 ; density_score 0.5222902494331066 : 10試行の平均SCORE = 0.1
# 3125 Episode: Finished with score 0.0 ; density_score 0.5318934240362813 : 10試行の平均SCORE = 0.1
# 3126 Episode: Finished with score 0.0 ; density_score 0.5408730158730158 : 10試行の平均SCORE = 0.1
# 3127 Episode: Finished with score 0.0 ; density_score 0.4447278911564626 : 10試行の平均SCORE = 0.1
# 3128 Episode: Finished with score 0.0 ; density_score 0.49911564625850335 : 10試行の平均SCORE = 0.1
# 3129 Episode: Finished with score 0.0 ; density_score 0.4837662337662337 : 10試行の平均SCORE = 0.1
# 3130 Episode: Finished with score 0.0 ; density_score 0.4805442176870748 : 10試行の平均SCORE = 0.0
# 3131 Episode: Finished with score 0.0 ; density_score 0.49248608534322813 : 10試行の平均SCORE = 0.0
# 3132 Episode: Finished with score 0.0 ; density_score 0.4727214055785484 : 10試行の平均SCORE = 0.0
# 3133 Episode: Finished with score 0.0 ; density_score 0.5108730158730159 : 10試行の平均SCORE = 0.0
# 3134 Episode: Finished with score 0.0 ; density_score 0.4875850340136054 : 10試行の平均SCORE = 0.0
# 3135 Episode: Finished with score 0.0 ; density_score 0.5063492063492063 : 10試行の平均SCORE = 0.0
# 3136 Episode: Finished with score 0.0 ; density_score 0.47120213120213117 : 10試行の平均SCORE = 0.0
# 3137 Episode: Finished with score 0.0 ; density_score 0.53421768707483 : 10試行の平均SCORE = 0.0
# 3138 Episode: Finished with score 0.0 ; density_score 0.5219727891156462 : 10試行の平均SCORE = 0.0
# 3139 Episode: Finished with score 0.0 ; density_score 0.4813945578231293 : 10試行の平均SCORE = 0.0
# 3140 Episode: Finished with score 1.0 ; density_score 0.5658163265306123 : 10試行の平均SCORE = 0.1
# 3141 Episode: Finished with score 3.0 ; density_score 0.47795918367346946 : 10試行の平均SCORE = 0.4
# 3142 Episode: Finished with score 1.0 ; density_score 0.5051360544217688 : 10試行の平均SCORE = 0.5
# 3143 Episode: Finished with score 0.0 ; density_score 0.49523809523809526 : 10試行の平均SCORE = 0.5
# 3144 Episode: Finished with score 0.0 ; density_score 0.4997732426303855 : 10試行の平均SCORE = 0.5
# 3145 Episode: Finished with score 1.0 ; density_score 0.5252380952380952 : 10試行の平均SCORE = 0.6
# 3146 Episode: Finished with score 0.0 ; density_score 0.47292517006802726 : 10試行の平均SCORE = 0.6
# 3147 Episode: Finished with score 0.0 ; density_score 0.48715728715728707 : 10試行の平均SCORE = 0.6
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Desktop\tetris_by_nim\tetris_env.py in step(self, i)
#      65             try:
# ---> 66                 am, field, reward, done = self._str_to_arr(self._step(i).decode())
#      67                 break
#
# OSError: exception: access violation writing 0x00000001C61DB018
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-15a15d29ad2b> in <module>
#     231
#     232 tetris_envi = Environment()
# --> 233 tetris_envi.run()
#
# <ipython-input-1-15a15d29ad2b> in run(self)
#     185             for step in range(MAX_STEPS):
#     186                 action = self.agent.get_action(state, episode)
# --> 187                 am, field, step_reward, done = self.env.step(action.item())
#     188                 observation_next = make_observation(am, field)
#     189
#
# ~\Desktop\tetris_by_nim\tetris_env.py in step(self, i)
#      68             except OSError:
#      69                 # print("retry")
# ---> 70                 self._revert()
#      71                 continue
#      72
#
# OSError: exception: access violation writing 0x0000000208851018
